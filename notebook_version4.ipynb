# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split, TensorDataset
from torch.optim.lr_scheduler import StepLR
from PIL import Image
import torch.optim.lr_scheduler as lr_scheduler

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_1
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_2
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/batches.meta
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/test_batch
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_3
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_5
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_4
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/readme.html

# %% [markdown]
# # Model Setting

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNetdl():
    return ResNet(BasicBlock, [1, 1, 1, 1])

# %% [markdown]
# # Training dataset

# %%
# auto. choose CPU or GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Function to load CIFAR-10 dataset
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Specify the directory containing CIFAR-10 batches
cifar10_dir = '/kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py'

# Load metadata (labels)
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = [label.decode('utf-8') for label in meta_data_dict[b'label_names']]

# Load training data
train_data = []
train_labels = []
for i in range(1, 6):
    batch = load_cifar_batch(os.path.join(cifar10_dir, f'data_batch_{i}'))
    train_data.append(batch[b'data'].astype(np.float32) / 255.0)
    train_labels += batch[b'labels']

train_data = np.vstack(train_data).reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)  # Convert to HWC format
train_labels = np.array(train_labels)

# Data augmentation and normalization
transform = transforms.Compose([
    transforms.ToPILImage(),  # Convert numpy array to PIL Image
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness = 0.1,contrast = 0.1,saturation = 0.1),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomAdjustSharpness(sharpness_factor = 2,p = 0.2),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261)),
    transforms.RandomErasing(p=0.2,scale=(0.02, 0.1),value=1.0, inplace=False)
])

# Convert to TensorDataset and apply transformations
class CustomCIFAR10Dataset(torch.utils.data.Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]
        label = self.labels[idx]

        if self.transform:
            img = self.transform(img)

        return img, label

train_dataset = CustomCIFAR10Dataset(train_data, train_labels, transform=transform)
# train_data
# Out:
# Using device: cuda

# %% [markdown]
# # Test dataset

# %%
# Load test dataset
cifar_test_path = '/kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl'
test_batch = load_cifar_batch(cifar_test_path)
test_images = test_batch[b'data'].astype(np.float32) / 255.0
test_images = test_images.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)  # Convert to HWC format

# Convert test dataset to Tensor
test_dataset = [(transform(img)) for img in test_images]
# test_images

# %%
# Split into training and validation sets
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=4)

# Train function
def train_model(model, train_loader, val_loader, epochs=50):
    # criterion = nn.CrossEntropyLoss()
    # optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    # optimizer = optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=1e-4) #change lr
    # scheduler = StepLR(optimizer, step_size=20, gamma=0.1)
    # scheduler = StepLR(optimizer, step_size=6, gamma=0.85)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
    
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        scheduler.step()
        print(f'Epoch {epoch+1}, Loss: {running_loss/len(train_loader)}, Validation Accuracy: {100 * correct / total}%')

# %%
# put models to devices (CPU/GPU)
model = ResNetdl()

# Two GPUs get double amount of parameters....???
# if torch.cuda.device_count() > 1:
#     print("Using", torch.cuda.device_count(), "GPUs!")
#     model = torch.nn.DataParallel(model)

model.to(device)

# Print the number of parameters
from torchsummary import summary
summary(model, (3, 32, 32))

# Train the model
train_model(model, train_loader, val_loader, epochs=200) #change epoch

# Generate submission file
model.eval()
predictions = []
with torch.no_grad():
    for images in test_loader:
        images = images.to(device) 
        outputs = model(images) 
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())

submission = pd.DataFrame({'ID': np.arange(len(predictions)), 'Labels': predictions})
submission.to_csv('/kaggle/working/submission3.csv', index=False)
print("Submission3 file saved.")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,728
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#            Conv2d-10          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-11          [-1, 128, 16, 16]             256
#            Conv2d-12          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-13          [-1, 128, 16, 16]             256
#        BasicBlock-14          [-1, 128, 16, 16]               0
#            Conv2d-15            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#            Conv2d-17            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-18            [-1, 256, 8, 8]             512
#            Conv2d-19            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-20            [-1, 256, 8, 8]             512
#        BasicBlock-21            [-1, 256, 8, 8]               0
#            Conv2d-22            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-23            [-1, 512, 4, 4]           1,024
#            Conv2d-24            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-25            [-1, 512, 4, 4]           1,024
#            Conv2d-26            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-27            [-1, 512, 4, 4]           1,024
#        BasicBlock-28            [-1, 512, 4, 4]               0
#            Linear-29                   [-1, 10]           5,130
# ================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.56
# Params size (MB): 18.70
# Estimated Total Size (MB): 25.28
# ----------------------------------------------------------------
# Epoch 1, Loss: 1.6469390148466283, Validation Accuracy: 47.04%
# Epoch 2, Loss: 1.2528437054292723, Validation Accuracy: 57.06%
# Epoch 3, Loss: 1.0613780798898502, Validation Accuracy: 63.7%
# Epoch 4, Loss: 0.9193499894304709, Validation Accuracy: 63.04%
# Epoch 5, Loss: 0.8204764021052555, Validation Accuracy: 62.98%
# Epoch 6, Loss: 0.7396335672925819, Validation Accuracy: 67.4%
# Epoch 7, Loss: 0.6840348623015664, Validation Accuracy: 74.78%
# Epoch 8, Loss: 0.6517431588674133, Validation Accuracy: 74.7%
# Epoch 9, Loss: 0.6192277741872452, Validation Accuracy: 73.66%
# Epoch 10, Loss: 0.6027886984361843, Validation Accuracy: 70.64%
# Epoch 11, Loss: 0.5799633831801739, Validation Accuracy: 73.28%
# Epoch 12, Loss: 0.5612046920101751, Validation Accuracy: 75.98%
# Epoch 13, Loss: 0.5500401629304345, Validation Accuracy: 73.66%
# Epoch 14, Loss: 0.5383494501425461, Validation Accuracy: 74.34%
# Epoch 15, Loss: 0.5267360283231194, Validation Accuracy: 76.64%
# Epoch 16, Loss: 0.5184622244401411, Validation Accuracy: 78.24%
# Epoch 17, Loss: 0.5116449533115056, Validation Accuracy: 75.34%
# Epoch 18, Loss: 0.5079460884867744, Validation Accuracy: 78.52%
# Epoch 19, Loss: 0.49876329404386605, Validation Accuracy: 75.56%
# Epoch 20, Loss: 0.49443319439888, Validation Accuracy: 73.92%
# Epoch 21, Loss: 0.4885963493619453, Validation Accuracy: 77.46%
# Epoch 22, Loss: 0.48082900064235384, Validation Accuracy: 77.64%
# Epoch 23, Loss: 0.4781752235510133, Validation Accuracy: 77.66%
# Epoch 24, Loss: 0.47440074367279356, Validation Accuracy: 76.34%
# Epoch 25, Loss: 0.4686449012634429, Validation Accuracy: 78.62%
# Epoch 26, Loss: 0.46929436261680996, Validation Accuracy: 80.02%
# Epoch 27, Loss: 0.46161152104931796, Validation Accuracy: 73.72%
# Epoch 28, Loss: 0.45965251474725927, Validation Accuracy: 75.46%
# Epoch 29, Loss: 0.4542061662809415, Validation Accuracy: 79.98%
# Epoch 30, Loss: 0.4550495926629413, Validation Accuracy: 78.72%
# Epoch 31, Loss: 0.4505558756857433, Validation Accuracy: 80.32%
# Epoch 32, Loss: 0.4540739926001565, Validation Accuracy: 80.1%
# Epoch 33, Loss: 0.4466691376556727, Validation Accuracy: 79.44%
# Epoch 34, Loss: 0.4511304786852138, Validation Accuracy: 82.7%
# Epoch 35, Loss: 0.4434292136098851, Validation Accuracy: 78.34%
# Epoch 36, Loss: 0.44787368195300753, Validation Accuracy: 80.66%
# Epoch 37, Loss: 0.4299018363976343, Validation Accuracy: 76.94%
# Epoch 38, Loss: 0.4348036138002168, Validation Accuracy: 79.86%
# Epoch 39, Loss: 0.43015965971757064, Validation Accuracy: 80.94%
# Epoch 40, Loss: 0.4339925638315352, Validation Accuracy: 79.8%
# Epoch 41, Loss: 0.43290360462428495, Validation Accuracy: 81.44%
# Epoch 42, Loss: 0.42859802818433806, Validation Accuracy: 78.18%
# Epoch 43, Loss: 0.4275109214623543, Validation Accuracy: 79.54%
# Epoch 44, Loss: 0.4204676967029544, Validation Accuracy: 76.36%
# Epoch 45, Loss: 0.4136728718030182, Validation Accuracy: 79.88%
# Epoch 46, Loss: 0.42326360106976196, Validation Accuracy: 81.4%
# Epoch 47, Loss: 0.41786419676447456, Validation Accuracy: 76.56%
# Epoch 48, Loss: 0.4150936047715897, Validation Accuracy: 77.44%
# Epoch 49, Loss: 0.41296970983967185, Validation Accuracy: 81.58%
# Epoch 50, Loss: 0.41563262146982277, Validation Accuracy: 78.56%
# Epoch 51, Loss: 0.4067983171817931, Validation Accuracy: 80.26%
# Epoch 52, Loss: 0.40975897369736974, Validation Accuracy: 81.56%
# Epoch 53, Loss: 0.40232769907875493, Validation Accuracy: 82.46%
# Epoch 54, Loss: 0.40258558467030525, Validation Accuracy: 78.98%
# Epoch 55, Loss: 0.4022944254631346, Validation Accuracy: 78.5%
# Epoch 56, Loss: 0.4015434488908134, Validation Accuracy: 77.34%
# Epoch 57, Loss: 0.3934357057918202, Validation Accuracy: 81.6%
# Epoch 58, Loss: 0.39309362990950997, Validation Accuracy: 80.64%
# Epoch 59, Loss: 0.3941286357797005, Validation Accuracy: 82.0%
# Epoch 60, Loss: 0.3869913600977849, Validation Accuracy: 79.94%
# Epoch 61, Loss: 0.39339566467837855, Validation Accuracy: 76.32%
# Epoch 62, Loss: 0.39396442439068446, Validation Accuracy: 76.56%
# Epoch 63, Loss: 0.38840156086635863, Validation Accuracy: 80.36%
# Epoch 64, Loss: 0.38223061490465293, Validation Accuracy: 83.06%
# Epoch 65, Loss: 0.3784244132905521, Validation Accuracy: 80.32%
# Epoch 66, Loss: 0.3861078340136869, Validation Accuracy: 80.54%
# Epoch 67, Loss: 0.3765288820405575, Validation Accuracy: 81.46%
# Epoch 68, Loss: 0.3819799411787905, Validation Accuracy: 78.58%
# Epoch 69, Loss: 0.37171318801119924, Validation Accuracy: 84.4%
# Epoch 70, Loss: 0.36487965869971295, Validation Accuracy: 76.22%
# Epoch 71, Loss: 0.37417101398618385, Validation Accuracy: 80.62%
# Epoch 72, Loss: 0.36671845987439156, Validation Accuracy: 83.36%
# Epoch 73, Loss: 0.36797707311978395, Validation Accuracy: 83.0%
# Epoch 74, Loss: 0.3611759914677929, Validation Accuracy: 77.92%
# Epoch 75, Loss: 0.3553671891039068, Validation Accuracy: 84.24%
# Epoch 76, Loss: 0.3612381117841737, Validation Accuracy: 82.68%
# Epoch 77, Loss: 0.3558601598593999, Validation Accuracy: 82.96%
# Epoch 78, Loss: 0.3498538314703513, Validation Accuracy: 83.42%
# Epoch 79, Loss: 0.35499998029660096, Validation Accuracy: 80.6%
# Epoch 80, Loss: 0.34633058914914727, Validation Accuracy: 83.48%
# Epoch 81, Loss: 0.346845615316521, Validation Accuracy: 81.36%
# Epoch 82, Loss: 0.3452279192226177, Validation Accuracy: 82.18%
# Epoch 83, Loss: 0.34323534758930857, Validation Accuracy: 82.6%
# Epoch 84, Loss: 0.3366432426582006, Validation Accuracy: 84.84%
# Epoch 85, Loss: 0.3389171270907603, Validation Accuracy: 85.12%
# Epoch 86, Loss: 0.33769306468523363, Validation Accuracy: 84.02%
# Epoch 87, Loss: 0.33178507968444715, Validation Accuracy: 85.14%
# Epoch 88, Loss: 0.3242570054717362, Validation Accuracy: 80.9%
# Epoch 89, Loss: 0.32611805615438655, Validation Accuracy: 80.32%
# Epoch 90, Loss: 0.3252340124242685, Validation Accuracy: 81.64%
# Epoch 91, Loss: 0.32366198004985397, Validation Accuracy: 84.52%
# Epoch 92, Loss: 0.31717102271928027, Validation Accuracy: 83.6%
# Epoch 93, Loss: 0.3139248073778369, Validation Accuracy: 83.42%
# Epoch 94, Loss: 0.3115760483779013, Validation Accuracy: 83.72%
# Epoch 95, Loss: 0.3110828088935126, Validation Accuracy: 84.4%
# Epoch 96, Loss: 0.3059003626165742, Validation Accuracy: 82.92%
# Epoch 97, Loss: 0.30495282050899486, Validation Accuracy: 86.12%
# Epoch 98, Loss: 0.30730246959931473, Validation Accuracy: 80.02%
# Epoch 99, Loss: 0.2973968698643148, Validation Accuracy: 85.52%
# Epoch 100, Loss: 0.2989635653793812, Validation Accuracy: 85.16%
# Epoch 101, Loss: 0.2940103157677434, Validation Accuracy: 83.92%
# Epoch 102, Loss: 0.29318540678782895, Validation Accuracy: 82.28%
# Epoch 103, Loss: 0.29172803613949905, Validation Accuracy: 84.4%
# Epoch 104, Loss: 0.2922428269362585, Validation Accuracy: 86.02%
# Epoch 105, Loss: 0.2801744070496749, Validation Accuracy: 86.16%
# Epoch 106, Loss: 0.27885649505664, Validation Accuracy: 85.96%
# Epoch 107, Loss: 0.27779824642295187, Validation Accuracy: 86.96%
# Epoch 108, Loss: 0.27715791372412985, Validation Accuracy: 85.4%
# Epoch 109, Loss: 0.27234134018759837, Validation Accuracy: 85.16%
# Epoch 110, Loss: 0.2686105596155606, Validation Accuracy: 86.2%
# Epoch 111, Loss: 0.26405402503653685, Validation Accuracy: 86.96%
# Epoch 112, Loss: 0.26390489578162407, Validation Accuracy: 82.72%
# Epoch 113, Loss: 0.26533841917460615, Validation Accuracy: 85.14%
# Epoch 114, Loss: 0.2566590017893098, Validation Accuracy: 83.3%
# Epoch 115, Loss: 0.25327875795350835, Validation Accuracy: 83.82%
# Epoch 116, Loss: 0.25055465203794564, Validation Accuracy: 85.52%
# Epoch 117, Loss: 0.24484356441958385, Validation Accuracy: 85.74%
# Epoch 118, Loss: 0.24955717622387139, Validation Accuracy: 83.44%
# Epoch 119, Loss: 0.23371981056830424, Validation Accuracy: 84.82%
# Epoch 120, Loss: 0.2414464647246694, Validation Accuracy: 87.2%
# Epoch 121, Loss: 0.22842533662068573, Validation Accuracy: 86.64%
# Epoch 122, Loss: 0.23494607995433564, Validation Accuracy: 85.8%
# Epoch 123, Loss: 0.22576783965765077, Validation Accuracy: 83.04%
# Epoch 124, Loss: 0.22392415299757637, Validation Accuracy: 86.08%
# Epoch 125, Loss: 0.22412815234962513, Validation Accuracy: 87.52%
# Epoch 126, Loss: 0.21758656908588653, Validation Accuracy: 87.52%
# Epoch 127, Loss: 0.21325774958611213, Validation Accuracy: 86.04%
# Epoch 128, Loss: 0.20613510796630924, Validation Accuracy: 84.92%
# Epoch 129, Loss: 0.20953215870328926, Validation Accuracy: 86.38%
# Epoch 130, Loss: 0.1991668999703093, Validation Accuracy: 88.44%
# Epoch 131, Loss: 0.1969246255995875, Validation Accuracy: 86.94%
# Epoch 132, Loss: 0.19538763518953187, Validation Accuracy: 87.44%
# Epoch 133, Loss: 0.19014038640836423, Validation Accuracy: 85.64%
# Epoch 134, Loss: 0.18897502342323688, Validation Accuracy: 88.26%
# Epoch 135, Loss: 0.17519467161037028, Validation Accuracy: 87.16%
# Epoch 136, Loss: 0.174381494987756, Validation Accuracy: 88.0%
# Epoch 137, Loss: 0.1789567438800904, Validation Accuracy: 86.12%
# Epoch 138, Loss: 0.17087759083898907, Validation Accuracy: 88.34%
# Epoch 139, Loss: 0.16475653582760555, Validation Accuracy: 88.42%
# Epoch 140, Loss: 0.1635308793788268, Validation Accuracy: 88.3%
# Epoch 141, Loss: 0.16194379949857565, Validation Accuracy: 88.9%
# Epoch 142, Loss: 0.15036952142095703, Validation Accuracy: 88.62%
# Epoch 143, Loss: 0.14832774964584547, Validation Accuracy: 89.08%
# Epoch 144, Loss: 0.1462267967237329, Validation Accuracy: 88.36%
# Epoch 145, Loss: 0.1438878757921471, Validation Accuracy: 87.4%
# Epoch 146, Loss: 0.14002940502144734, Validation Accuracy: 89.08%
# Epoch 147, Loss: 0.13363629536152902, Validation Accuracy: 89.32%
# Epoch 148, Loss: 0.12951763801869343, Validation Accuracy: 89.7%
# Epoch 149, Loss: 0.1323378219967708, Validation Accuracy: 89.24%
# Epoch 150, Loss: 0.12383073433937336, Validation Accuracy: 88.68%
# Epoch 151, Loss: 0.12090064317453653, Validation Accuracy: 88.26%
# Epoch 152, Loss: 0.11780730184082958, Validation Accuracy: 90.14%
# Epoch 153, Loss: 0.10988573712000455, Validation Accuracy: 89.76%
# Epoch 154, Loss: 0.10871876271399246, Validation Accuracy: 90.24%
# Epoch 155, Loss: 0.09830924711952155, Validation Accuracy: 90.64%
# Epoch 156, Loss: 0.09292030846700072, Validation Accuracy: 89.84%
# Epoch 157, Loss: 0.09655938818204132, Validation Accuracy: 90.06%
# Epoch 158, Loss: 0.09046389852565798, Validation Accuracy: 90.32%
# Epoch 159, Loss: 0.08633644077186049, Validation Accuracy: 90.9%
# Epoch 160, Loss: 0.08133697197031738, Validation Accuracy: 91.44%
# Epoch 161, Loss: 0.07362527254206891, Validation Accuracy: 89.96%
# Epoch 162, Loss: 0.07340556777357547, Validation Accuracy: 91.4%
# Epoch 163, Loss: 0.06803946251536465, Validation Accuracy: 90.86%
# Epoch 164, Loss: 0.06518592380664566, Validation Accuracy: 91.0%
# Epoch 165, Loss: 0.06233385335706936, Validation Accuracy: 91.26%
# Epoch 166, Loss: 0.059490614737362855, Validation Accuracy: 91.16%
# Epoch 167, Loss: 0.053062973043944854, Validation Accuracy: 91.04%
# Epoch 168, Loss: 0.051091033211295406, Validation Accuracy: 91.9%
# Epoch 169, Loss: 0.04826648077869322, Validation Accuracy: 91.76%
# Epoch 170, Loss: 0.044117778535688885, Validation Accuracy: 91.28%
# Epoch 171, Loss: 0.04461733787188264, Validation Accuracy: 91.84%
# Epoch 172, Loss: 0.042071175110653385, Validation Accuracy: 91.78%
# Epoch 173, Loss: 0.036564618076557635, Validation Accuracy: 91.7%
# Epoch 174, Loss: 0.03554289498292333, Validation Accuracy: 92.3%
# Epoch 175, Loss: 0.03343223989015149, Validation Accuracy: 91.3%
# Epoch 176, Loss: 0.03197542711065828, Validation Accuracy: 91.68%
# Epoch 177, Loss: 0.02912961522815749, Validation Accuracy: 92.04%
# Epoch 178, Loss: 0.02819235246385109, Validation Accuracy: 91.82%
# Epoch 179, Loss: 0.026745848659298976, Validation Accuracy: 92.58%
# Epoch 180, Loss: 0.02558180766672277, Validation Accuracy: 92.38%
# Epoch 181, Loss: 0.024471410970198285, Validation Accuracy: 92.46%
# Epoch 182, Loss: 0.022923460060899906, Validation Accuracy: 92.18%
# Epoch 183, Loss: 0.022082722425693646, Validation Accuracy: 92.2%
# Epoch 184, Loss: 0.022052954574147323, Validation Accuracy: 92.64%
# Epoch 185, Loss: 0.02060983844421571, Validation Accuracy: 92.48%
# Epoch 186, Loss: 0.019933313160436228, Validation Accuracy: 92.54%
# Epoch 187, Loss: 0.01908709699108096, Validation Accuracy: 92.94%
# Epoch 188, Loss: 0.01884749248181999, Validation Accuracy: 92.74%
# Epoch 189, Loss: 0.01901149213253203, Validation Accuracy: 92.78%
# Epoch 190, Loss: 0.018723509497993455, Validation Accuracy: 93.06%
# Epoch 191, Loss: 0.017549980486034077, Validation Accuracy: 92.44%
# Epoch 192, Loss: 0.017842656211789952, Validation Accuracy: 92.9%
# Epoch 193, Loss: 0.01710312621534368, Validation Accuracy: 92.46%
# Epoch 194, Loss: 0.01600354171651733, Validation Accuracy: 92.48%
# Epoch 195, Loss: 0.016306304465450176, Validation Accuracy: 92.6%
# Epoch 196, Loss: 0.015891704975563862, Validation Accuracy: 92.76%
# Epoch 197, Loss: 0.01688736831023231, Validation Accuracy: 92.76%
# Epoch 198, Loss: 0.01669626364045226, Validation Accuracy: 93.46%
# Epoch 199, Loss: 0.016726258343127978, Validation Accuracy: 92.32%
# Epoch 200, Loss: 0.01680311990243023, Validation Accuracy: 92.56%
# Submission3 file saved.

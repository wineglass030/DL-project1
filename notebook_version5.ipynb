# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split, TensorDataset
from torch.optim.lr_scheduler import StepLR
from PIL import Image
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_1
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_2
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/batches.meta
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/test_batch
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_3
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_5
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_4
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/readme.html

# %% [markdown]
# # Model Setting

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNetdl():
    return ResNet(BasicBlock, [1, 1, 1, 1])

# %% [markdown]
# # Training dataset

# %%
# auto. choose CPU or GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Function to load CIFAR-10 dataset
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Specify the directory containing CIFAR-10 batches
cifar10_dir = '/kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py'

# Load metadata (labels)
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = [label.decode('utf-8') for label in meta_data_dict[b'label_names']]

# Load training data
train_data = []
train_labels = []
for i in range(1, 6):
    batch = load_cifar_batch(os.path.join(cifar10_dir, f'data_batch_{i}'))
    train_data.append(batch[b'data'])
    train_labels += batch[b'labels']

train_data = np.vstack(train_data).reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)  # Convert to HWC format
train_labels = np.array(train_labels)

# Data augmentation and normalization
transform = transforms.Compose([
    transforms.ToPILImage(),  # Convert numpy array to PIL Image
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness = 0.1,contrast = 0.1,saturation = 0.1),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomAdjustSharpness(sharpness_factor = 2,p = 0.2),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261)),
    transforms.RandomErasing(p=0.2,scale=(0.02, 0.1),value=1.0, inplace=False)
])

# Convert to TensorDataset and apply transformations
class CustomCIFAR10Dataset(torch.utils.data.Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]
        label = self.labels[idx]

        if self.transform:
            img = self.transform(img)

        return img, label

train_dataset = CustomCIFAR10Dataset(train_data, train_labels, transform=transform)

# Function to display the first image
# def show_first_image(images, labels, label_names):
#     first_image = images[0]  # Get the first image
#     first_label = labels[0]  # Get the first label

#     # Display the image
#     plt.imshow(first_image)
#     plt.title(f"Label: {label_names[first_label]}")
#     plt.axis('off')
#     plt.show()

# # Call the function to display the first image
# show_first_image(train_data, train_labels, label_names)
# Out:
# Using device: cuda

# %% [markdown]
# # Validation dataset

# %%
test_transform = transforms.Compose([
    transforms.ToPILImage(),  # Convert numpy array to PIL Image
    transforms.ToTensor(),   # Convert [0,255] to [0.0,1.0]
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
])

batch_test_dict = load_cifar_batch(os.path.join(cifar10_dir, 'test_batch'))
val_images = batch_test_dict[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
val_labels = np.array(batch_test_dict[b'labels'])

val_dataset = CustomCIFAR10Dataset(val_images, val_labels, transform=test_transform)

# # Function to display the first image of a dataset
# def show_first_image(images, labels, label_names, transform=None):
#     first_image = images[0]  # Get the first image
#     first_label = labels[0]  # Get the first label

#     # Apply transformation if provided
#     if transform:
#         first_image = transform(first_image)

#     # Denormalize the image for visualization
#     mean = torch.tensor([0.4914, 0.4822, 0.4465]).view(3, 1, 1)
#     std = torch.tensor([0.247, 0.243, 0.261]).view(3, 1, 1)
#     first_image = first_image * std + mean

#     # Convert from tensor to numpy and transpose to HWC format
#     first_image = first_image.permute(1, 2, 0).numpy()

#     # Display the image
#     plt.imshow(first_image)
#     plt.title(f"Label: {label_names[first_label]}")
#     plt.axis('off')
#     plt.show()

# # Call the function to display the first image of the validation dataset
# show_first_image(val_images, val_labels, label_names, transform=test_transform)

# %% [markdown]
# # Test dataset

# %%
# Load test dataset
cifar_test_path = '/kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl'
test_batch = load_cifar_batch(cifar_test_path)
test_images = test_batch[b'data']

# Convert test dataset to Tensor
test_dataset = [(test_transform(img),) for img in test_images]

# def show_first_test_image(test_images, transform=None):
#     first_image = test_images[9]  # Get the first image

#     # Apply transformation if provided
#     if transform:
#         first_image = transform(first_image)

#     # Denormalize the image for visualization
#     mean = torch.tensor([0.4914, 0.4822, 0.4465]).view(3, 1, 1)
#     std = torch.tensor([0.247, 0.243, 0.261]).view(3, 1, 1)
#     first_image = first_image * std + mean

#     # Convert from tensor to numpy and transpose to HWC format
#     first_image = first_image.permute(1, 2, 0).numpy()

#     # Display the image
#     plt.imshow(first_image)
#     plt.axis('off')
#     plt.show()

# # Call the function to display the first image of the test dataset
# show_first_test_image(test_images, transform=test_transform)

# %%
# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=4)

# Train function
def train_model(model, train_loader, val_loader, epochs=50):
    # criterion = nn.CrossEntropyLoss()
    # optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    # optimizer = optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=1e-4) #change lr
    # scheduler = StepLR(optimizer, step_size=20, gamma=0.1)
    # scheduler = StepLR(optimizer, step_size=6, gamma=0.85)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
    
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(epochs):
        # Training Phase
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct / total
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        # Validation Phase
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_loss /= len(val_loader)
        val_acc = 100 * correct / total
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        scheduler.step()
        print(f'Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')

    # Plot Losses
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, epochs + 1), train_losses, label='Train Loss', color='red')
    plt.plot(range(1, epochs + 1), val_losses, label='Validation Loss', color='blue')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train Loss & Validation Loss')
    plt.legend()
    plt.grid()
    plt.show()

    # Plot Accuracies
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, epochs + 1), train_accuracies, label='Train Accuracy', color='green')
    plt.plot(range(1, epochs + 1), val_accuracies, label='Validation Accuracy', color='purple')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('Train Accuracy & Validation Accuracy')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# put models to devices (CPU/GPU)
model = ResNetdl()

model.to(device)

# Print the number of parameters
from torchsummary import summary
summary(model, (3, 32, 32))

# Train the model
train_model(model, train_loader, val_loader, epochs=200) #change epoch

# Generate submission file
model.eval()
predictions = []
with torch.no_grad():
    for batch in test_loader:
        images = batch[0].to(device)
        outputs = model(images) 
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())

submission = pd.DataFrame({'ID': np.arange(len(predictions)), 'Labels': predictions})
submission.to_csv('/kaggle/working/submission1.csv', index=False)
print("Submission1 file saved.")
print(submission.head(10))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,728
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#            Conv2d-10          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-11          [-1, 128, 16, 16]             256
#            Conv2d-12          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-13          [-1, 128, 16, 16]             256
#        BasicBlock-14          [-1, 128, 16, 16]               0
#            Conv2d-15            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#            Conv2d-17            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-18            [-1, 256, 8, 8]             512
#            Conv2d-19            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-20            [-1, 256, 8, 8]             512
#        BasicBlock-21            [-1, 256, 8, 8]               0
#            Conv2d-22            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-23            [-1, 512, 4, 4]           1,024
#            Conv2d-24            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-25            [-1, 512, 4, 4]           1,024
#            Conv2d-26            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-27            [-1, 512, 4, 4]           1,024
#        BasicBlock-28            [-1, 512, 4, 4]               0
#            Linear-29                   [-1, 10]           5,130
# ================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.56
# Params size (MB): 18.70
# Estimated Total Size (MB): 25.28
# ----------------------------------------------------------------
# Epoch 1, Train Loss: 1.6348, Train Acc: 39.85%, Val Loss: 1.3311, Val Acc: 50.59%
# Epoch 2, Train Loss: 1.2088, Train Acc: 56.54%, Val Loss: 0.9869, Val Acc: 64.84%
# Epoch 3, Train Loss: 1.0063, Train Acc: 64.39%, Val Loss: 0.9065, Val Acc: 67.96%
# Epoch 4, Train Loss: 0.8694, Train Acc: 69.32%, Val Loss: 0.8787, Val Acc: 70.40%
# Epoch 5, Train Loss: 0.7683, Train Acc: 73.24%, Val Loss: 0.8252, Val Acc: 71.39%
# Epoch 6, Train Loss: 0.6986, Train Acc: 75.74%, Val Loss: 0.8250, Val Acc: 72.30%
# Epoch 7, Train Loss: 0.6602, Train Acc: 77.03%, Val Loss: 0.6194, Val Acc: 78.23%
# Epoch 8, Train Loss: 0.6261, Train Acc: 78.28%, Val Loss: 0.7339, Val Acc: 76.54%
# Epoch 9, Train Loss: 0.5988, Train Acc: 79.30%, Val Loss: 0.7223, Val Acc: 76.06%
# Epoch 10, Train Loss: 0.5841, Train Acc: 79.92%, Val Loss: 0.7051, Val Acc: 76.37%
# Epoch 11, Train Loss: 0.5630, Train Acc: 80.51%, Val Loss: 0.5081, Val Acc: 82.75%
# Epoch 12, Train Loss: 0.5492, Train Acc: 80.89%, Val Loss: 0.5526, Val Acc: 81.74%
# Epoch 13, Train Loss: 0.5357, Train Acc: 81.59%, Val Loss: 0.6241, Val Acc: 79.45%
# Epoch 14, Train Loss: 0.5324, Train Acc: 81.60%, Val Loss: 0.6362, Val Acc: 78.90%
# Epoch 15, Train Loss: 0.5188, Train Acc: 82.07%, Val Loss: 0.6498, Val Acc: 78.92%
# Epoch 16, Train Loss: 0.5145, Train Acc: 82.32%, Val Loss: 0.7680, Val Acc: 75.70%
# Epoch 17, Train Loss: 0.5024, Train Acc: 82.81%, Val Loss: 0.4912, Val Acc: 83.46%
# Epoch 18, Train Loss: 0.4971, Train Acc: 82.92%, Val Loss: 0.6353, Val Acc: 79.06%
# Epoch 19, Train Loss: 0.4877, Train Acc: 83.27%, Val Loss: 0.7941, Val Acc: 74.96%
# Epoch 20, Train Loss: 0.4866, Train Acc: 83.30%, Val Loss: 0.4693, Val Acc: 84.04%
# Epoch 21, Train Loss: 0.4880, Train Acc: 83.35%, Val Loss: 0.9771, Val Acc: 71.62%
# Epoch 22, Train Loss: 0.4809, Train Acc: 83.48%, Val Loss: 0.5824, Val Acc: 80.30%
# Epoch 23, Train Loss: 0.4782, Train Acc: 83.47%, Val Loss: 0.5717, Val Acc: 81.67%
# Epoch 24, Train Loss: 0.4690, Train Acc: 83.76%, Val Loss: 0.5139, Val Acc: 82.89%
# Epoch 25, Train Loss: 0.4682, Train Acc: 83.96%, Val Loss: 0.4604, Val Acc: 84.84%
# Epoch 26, Train Loss: 0.4639, Train Acc: 84.26%, Val Loss: 0.4533, Val Acc: 84.66%
# Epoch 27, Train Loss: 0.4607, Train Acc: 84.24%, Val Loss: 0.5719, Val Acc: 81.65%
# Epoch 28, Train Loss: 0.4600, Train Acc: 84.22%, Val Loss: 0.6345, Val Acc: 79.29%
# Epoch 29, Train Loss: 0.4515, Train Acc: 84.43%, Val Loss: 0.5248, Val Acc: 81.82%
# Epoch 30, Train Loss: 0.4527, Train Acc: 84.43%, Val Loss: 0.5524, Val Acc: 81.20%
# Epoch 31, Train Loss: 0.4545, Train Acc: 84.38%, Val Loss: 0.6190, Val Acc: 79.80%
# Epoch 32, Train Loss: 0.4475, Train Acc: 84.58%, Val Loss: 0.5001, Val Acc: 83.08%
# Epoch 33, Train Loss: 0.4464, Train Acc: 84.54%, Val Loss: 0.4773, Val Acc: 83.96%
# Epoch 34, Train Loss: 0.4418, Train Acc: 84.86%, Val Loss: 0.5503, Val Acc: 82.64%
# Epoch 35, Train Loss: 0.4409, Train Acc: 84.85%, Val Loss: 0.5231, Val Acc: 82.54%
# Epoch 36, Train Loss: 0.4455, Train Acc: 84.64%, Val Loss: 0.5438, Val Acc: 81.27%
# Epoch 37, Train Loss: 0.4403, Train Acc: 84.79%, Val Loss: 0.5878, Val Acc: 80.16%
# Epoch 38, Train Loss: 0.4366, Train Acc: 85.05%, Val Loss: 0.5226, Val Acc: 82.24%
# Epoch 39, Train Loss: 0.4321, Train Acc: 85.01%, Val Loss: 0.5625, Val Acc: 81.60%
# Epoch 40, Train Loss: 0.4329, Train Acc: 84.91%, Val Loss: 0.4605, Val Acc: 84.39%
# Epoch 41, Train Loss: 0.4280, Train Acc: 85.19%, Val Loss: 0.4559, Val Acc: 84.92%
# Epoch 42, Train Loss: 0.4288, Train Acc: 85.25%, Val Loss: 0.5463, Val Acc: 81.24%
# Epoch 43, Train Loss: 0.4228, Train Acc: 85.32%, Val Loss: 0.5720, Val Acc: 82.45%
# Epoch 44, Train Loss: 0.4244, Train Acc: 85.34%, Val Loss: 0.5419, Val Acc: 82.26%
# Epoch 45, Train Loss: 0.4188, Train Acc: 85.48%, Val Loss: 0.5232, Val Acc: 83.43%
# Epoch 46, Train Loss: 0.4219, Train Acc: 85.59%, Val Loss: 0.4824, Val Acc: 84.00%
# Epoch 47, Train Loss: 0.4238, Train Acc: 85.55%, Val Loss: 0.5490, Val Acc: 81.84%
# Epoch 48, Train Loss: 0.4176, Train Acc: 85.62%, Val Loss: 0.4696, Val Acc: 83.99%
# Epoch 49, Train Loss: 0.4075, Train Acc: 86.15%, Val Loss: 0.5938, Val Acc: 80.92%
# Epoch 50, Train Loss: 0.4115, Train Acc: 85.71%, Val Loss: 0.4752, Val Acc: 84.60%
# Epoch 51, Train Loss: 0.4160, Train Acc: 85.78%, Val Loss: 0.7083, Val Acc: 77.94%
# Epoch 52, Train Loss: 0.4099, Train Acc: 85.82%, Val Loss: 0.4033, Val Acc: 86.28%
# Epoch 53, Train Loss: 0.4052, Train Acc: 86.12%, Val Loss: 0.5657, Val Acc: 81.91%
# Epoch 54, Train Loss: 0.4106, Train Acc: 85.88%, Val Loss: 0.5207, Val Acc: 82.03%
# Epoch 55, Train Loss: 0.4048, Train Acc: 86.07%, Val Loss: 0.7789, Val Acc: 76.87%
# Epoch 56, Train Loss: 0.4016, Train Acc: 86.07%, Val Loss: 0.5658, Val Acc: 82.11%
# Epoch 57, Train Loss: 0.4003, Train Acc: 86.33%, Val Loss: 0.4407, Val Acc: 85.49%
# Epoch 58, Train Loss: 0.3947, Train Acc: 86.44%, Val Loss: 0.5516, Val Acc: 80.92%
# Epoch 59, Train Loss: 0.3959, Train Acc: 86.40%, Val Loss: 0.4538, Val Acc: 85.13%
# Epoch 60, Train Loss: 0.3884, Train Acc: 86.64%, Val Loss: 0.4312, Val Acc: 85.60%
# Epoch 61, Train Loss: 0.3996, Train Acc: 86.12%, Val Loss: 0.6562, Val Acc: 79.93%
# Epoch 62, Train Loss: 0.3934, Train Acc: 86.55%, Val Loss: 0.4780, Val Acc: 84.41%
# Epoch 63, Train Loss: 0.3939, Train Acc: 86.44%, Val Loss: 0.4317, Val Acc: 85.68%
# Epoch 64, Train Loss: 0.3886, Train Acc: 86.52%, Val Loss: 0.4562, Val Acc: 84.94%
# Epoch 65, Train Loss: 0.3838, Train Acc: 86.78%, Val Loss: 0.4782, Val Acc: 84.36%
# Epoch 66, Train Loss: 0.3841, Train Acc: 86.82%, Val Loss: 0.5339, Val Acc: 82.58%
# Epoch 67, Train Loss: 0.3890, Train Acc: 86.69%, Val Loss: 0.4587, Val Acc: 84.86%
# Epoch 68, Train Loss: 0.3792, Train Acc: 86.88%, Val Loss: 0.4832, Val Acc: 84.46%
# Epoch 69, Train Loss: 0.3773, Train Acc: 86.98%, Val Loss: 0.6376, Val Acc: 79.04%
# Epoch 70, Train Loss: 0.3749, Train Acc: 87.01%, Val Loss: 0.4610, Val Acc: 84.85%
# Epoch 71, Train Loss: 0.3744, Train Acc: 87.27%, Val Loss: 0.4399, Val Acc: 85.97%
# Epoch 72, Train Loss: 0.3666, Train Acc: 87.40%, Val Loss: 0.4475, Val Acc: 84.88%
# Epoch 73, Train Loss: 0.3736, Train Acc: 87.15%, Val Loss: 0.4712, Val Acc: 84.48%
# Epoch 74, Train Loss: 0.3644, Train Acc: 87.39%, Val Loss: 0.5016, Val Acc: 83.68%
# Epoch 75, Train Loss: 0.3644, Train Acc: 87.42%, Val Loss: 0.4590, Val Acc: 84.61%
# Epoch 76, Train Loss: 0.3637, Train Acc: 87.41%, Val Loss: 0.4160, Val Acc: 85.53%
# Epoch 77, Train Loss: 0.3609, Train Acc: 87.66%, Val Loss: 0.4279, Val Acc: 85.74%
# Epoch 78, Train Loss: 0.3575, Train Acc: 87.74%, Val Loss: 0.4446, Val Acc: 85.14%
# Epoch 79, Train Loss: 0.3579, Train Acc: 87.44%, Val Loss: 0.4672, Val Acc: 84.73%
# Epoch 80, Train Loss: 0.3534, Train Acc: 87.81%, Val Loss: 0.4187, Val Acc: 86.32%
# Epoch 81, Train Loss: 0.3527, Train Acc: 87.84%, Val Loss: 0.4531, Val Acc: 85.48%
# Epoch 82, Train Loss: 0.3531, Train Acc: 87.75%, Val Loss: 0.3687, Val Acc: 87.87%
# Epoch 83, Train Loss: 0.3477, Train Acc: 88.00%, Val Loss: 0.5271, Val Acc: 83.30%
# Epoch 84, Train Loss: 0.3444, Train Acc: 88.09%, Val Loss: 0.4661, Val Acc: 85.10%
# Epoch 85, Train Loss: 0.3424, Train Acc: 88.08%, Val Loss: 0.4185, Val Acc: 86.25%
# Epoch 86, Train Loss: 0.3401, Train Acc: 88.09%, Val Loss: 0.4022, Val Acc: 87.14%
# Epoch 87, Train Loss: 0.3375, Train Acc: 88.35%, Val Loss: 0.4513, Val Acc: 85.84%
# Epoch 88, Train Loss: 0.3353, Train Acc: 88.50%, Val Loss: 0.4728, Val Acc: 85.42%
# Epoch 89, Train Loss: 0.3349, Train Acc: 88.45%, Val Loss: 0.3818, Val Acc: 86.78%
# Epoch 90, Train Loss: 0.3295, Train Acc: 88.69%, Val Loss: 0.3787, Val Acc: 87.42%
# Epoch 91, Train Loss: 0.3266, Train Acc: 88.71%, Val Loss: 0.3728, Val Acc: 87.81%
# Epoch 92, Train Loss: 0.3258, Train Acc: 88.78%, Val Loss: 0.4340, Val Acc: 85.95%
# Epoch 93, Train Loss: 0.3269, Train Acc: 88.68%, Val Loss: 0.4265, Val Acc: 85.55%
# Epoch 94, Train Loss: 0.3220, Train Acc: 88.93%, Val Loss: 0.5406, Val Acc: 83.66%
# Epoch 95, Train Loss: 0.3170, Train Acc: 88.96%, Val Loss: 0.3900, Val Acc: 86.89%
# Epoch 96, Train Loss: 0.3174, Train Acc: 89.07%, Val Loss: 0.4609, Val Acc: 85.29%
# Epoch 97, Train Loss: 0.3139, Train Acc: 89.16%, Val Loss: 0.3893, Val Acc: 87.25%
# Epoch 98, Train Loss: 0.3103, Train Acc: 89.36%, Val Loss: 0.4051, Val Acc: 86.83%
# Epoch 99, Train Loss: 0.3052, Train Acc: 89.55%, Val Loss: 0.4021, Val Acc: 87.10%
# Epoch 100, Train Loss: 0.3064, Train Acc: 89.44%, Val Loss: 0.3482, Val Acc: 88.78%
# Epoch 101, Train Loss: 0.2974, Train Acc: 89.77%, Val Loss: 0.3959, Val Acc: 87.05%
# Epoch 102, Train Loss: 0.3035, Train Acc: 89.56%, Val Loss: 0.3760, Val Acc: 87.67%
# Epoch 103, Train Loss: 0.2983, Train Acc: 89.79%, Val Loss: 0.3533, Val Acc: 88.04%
# Epoch 104, Train Loss: 0.2976, Train Acc: 89.70%, Val Loss: 0.4644, Val Acc: 86.12%
# Epoch 105, Train Loss: 0.2900, Train Acc: 90.00%, Val Loss: 0.4063, Val Acc: 86.75%
# Epoch 106, Train Loss: 0.2886, Train Acc: 90.04%, Val Loss: 0.3961, Val Acc: 87.45%
# Epoch 107, Train Loss: 0.2888, Train Acc: 89.84%, Val Loss: 0.3436, Val Acc: 88.88%
# Epoch 108, Train Loss: 0.2802, Train Acc: 90.33%, Val Loss: 0.3666, Val Acc: 88.08%
# Epoch 109, Train Loss: 0.2809, Train Acc: 90.25%, Val Loss: 0.3512, Val Acc: 88.26%
# Epoch 110, Train Loss: 0.2796, Train Acc: 90.30%, Val Loss: 0.3831, Val Acc: 87.60%
# Epoch 111, Train Loss: 0.2754, Train Acc: 90.50%, Val Loss: 0.3244, Val Acc: 88.93%
# Epoch 112, Train Loss: 0.2662, Train Acc: 90.88%, Val Loss: 0.4435, Val Acc: 86.00%
# Epoch 113, Train Loss: 0.2672, Train Acc: 90.69%, Val Loss: 0.3484, Val Acc: 89.03%
# Epoch 114, Train Loss: 0.2649, Train Acc: 90.83%, Val Loss: 0.4337, Val Acc: 86.42%
# Epoch 115, Train Loss: 0.2629, Train Acc: 90.84%, Val Loss: 0.3510, Val Acc: 89.06%
# Epoch 116, Train Loss: 0.2576, Train Acc: 91.11%, Val Loss: 0.3648, Val Acc: 88.18%
# Epoch 117, Train Loss: 0.2534, Train Acc: 91.23%, Val Loss: 0.3876, Val Acc: 87.97%
# Epoch 118, Train Loss: 0.2548, Train Acc: 91.02%, Val Loss: 0.3417, Val Acc: 89.02%
# Epoch 119, Train Loss: 0.2477, Train Acc: 91.47%, Val Loss: 0.3533, Val Acc: 88.45%
# Epoch 120, Train Loss: 0.2413, Train Acc: 91.67%, Val Loss: 0.3030, Val Acc: 90.06%
# Epoch 121, Train Loss: 0.2394, Train Acc: 91.70%, Val Loss: 0.3512, Val Acc: 88.67%
# Epoch 122, Train Loss: 0.2453, Train Acc: 91.44%, Val Loss: 0.3369, Val Acc: 88.91%
# Epoch 123, Train Loss: 0.2351, Train Acc: 91.87%, Val Loss: 0.3765, Val Acc: 88.20%
# Epoch 124, Train Loss: 0.2344, Train Acc: 91.67%, Val Loss: 0.3908, Val Acc: 87.89%
# Epoch 125, Train Loss: 0.2295, Train Acc: 92.03%, Val Loss: 0.3183, Val Acc: 89.90%
# Epoch 126, Train Loss: 0.2220, Train Acc: 92.38%, Val Loss: 0.3362, Val Acc: 89.26%
# Epoch 127, Train Loss: 0.2200, Train Acc: 92.33%, Val Loss: 0.3388, Val Acc: 89.03%
# Epoch 128, Train Loss: 0.2146, Train Acc: 92.57%, Val Loss: 0.3106, Val Acc: 89.87%
# Epoch 129, Train Loss: 0.2148, Train Acc: 92.57%, Val Loss: 0.3020, Val Acc: 90.05%
# Epoch 130, Train Loss: 0.2088, Train Acc: 92.74%, Val Loss: 0.3691, Val Acc: 88.66%
# Epoch 131, Train Loss: 0.2062, Train Acc: 92.75%, Val Loss: 0.3110, Val Acc: 90.20%
# Epoch 132, Train Loss: 0.2045, Train Acc: 92.90%, Val Loss: 0.2994, Val Acc: 90.33%
# Epoch 133, Train Loss: 0.1976, Train Acc: 93.11%, Val Loss: 0.3487, Val Acc: 89.21%
# Epoch 134, Train Loss: 0.2013, Train Acc: 93.04%, Val Loss: 0.2990, Val Acc: 90.46%
# Epoch 135, Train Loss: 0.1917, Train Acc: 93.31%, Val Loss: 0.3140, Val Acc: 90.06%
# Epoch 136, Train Loss: 0.1923, Train Acc: 93.35%, Val Loss: 0.2870, Val Acc: 90.95%
# Epoch 137, Train Loss: 0.1861, Train Acc: 93.50%, Val Loss: 0.3273, Val Acc: 89.69%
# Epoch 138, Train Loss: 0.1815, Train Acc: 93.80%, Val Loss: 0.3146, Val Acc: 89.72%
# Epoch 139, Train Loss: 0.1813, Train Acc: 93.74%, Val Loss: 0.2804, Val Acc: 90.90%
# Epoch 140, Train Loss: 0.1737, Train Acc: 94.04%, Val Loss: 0.2758, Val Acc: 90.99%
# Epoch 141, Train Loss: 0.1675, Train Acc: 94.15%, Val Loss: 0.2932, Val Acc: 90.39%
# Epoch 142, Train Loss: 0.1612, Train Acc: 94.41%, Val Loss: 0.2869, Val Acc: 91.18%
# Epoch 143, Train Loss: 0.1614, Train Acc: 94.45%, Val Loss: 0.3393, Val Acc: 89.47%
# Epoch 144, Train Loss: 0.1597, Train Acc: 94.40%, Val Loss: 0.3133, Val Acc: 90.59%
# Epoch 145, Train Loss: 0.1573, Train Acc: 94.65%, Val Loss: 0.2673, Val Acc: 91.59%
# Epoch 146, Train Loss: 0.1492, Train Acc: 94.91%, Val Loss: 0.3091, Val Acc: 90.60%
# Epoch 147, Train Loss: 0.1481, Train Acc: 94.87%, Val Loss: 0.2837, Val Acc: 90.93%
# Epoch 148, Train Loss: 0.1411, Train Acc: 95.12%, Val Loss: 0.2936, Val Acc: 91.01%
# Epoch 149, Train Loss: 0.1332, Train Acc: 95.45%, Val Loss: 0.2646, Val Acc: 92.07%
# Epoch 150, Train Loss: 0.1344, Train Acc: 95.31%, Val Loss: 0.3026, Val Acc: 90.86%
# Epoch 151, Train Loss: 0.1268, Train Acc: 95.57%, Val Loss: 0.2918, Val Acc: 91.52%
# Epoch 152, Train Loss: 0.1247, Train Acc: 95.64%, Val Loss: 0.2634, Val Acc: 91.75%
# Epoch 153, Train Loss: 0.1188, Train Acc: 95.98%, Val Loss: 0.2781, Val Acc: 91.96%
# Epoch 154, Train Loss: 0.1149, Train Acc: 96.07%, Val Loss: 0.2796, Val Acc: 92.02%
# Epoch 155, Train Loss: 0.1114, Train Acc: 96.16%, Val Loss: 0.2595, Val Acc: 92.10%
# Epoch 156, Train Loss: 0.1024, Train Acc: 96.54%, Val Loss: 0.2523, Val Acc: 92.23%
# Epoch 157, Train Loss: 0.1016, Train Acc: 96.57%, Val Loss: 0.3043, Val Acc: 91.41%
# Epoch 158, Train Loss: 0.0994, Train Acc: 96.68%, Val Loss: 0.2506, Val Acc: 92.45%
# Epoch 159, Train Loss: 0.0962, Train Acc: 96.74%, Val Loss: 0.2534, Val Acc: 92.37%
# Epoch 160, Train Loss: 0.0879, Train Acc: 96.98%, Val Loss: 0.2537, Val Acc: 92.54%
# Epoch 161, Train Loss: 0.0863, Train Acc: 97.08%, Val Loss: 0.2570, Val Acc: 92.38%
# Epoch 162, Train Loss: 0.0831, Train Acc: 97.25%, Val Loss: 0.2384, Val Acc: 92.79%
# Epoch 163, Train Loss: 0.0757, Train Acc: 97.51%, Val Loss: 0.2530, Val Acc: 92.50%
# Epoch 164, Train Loss: 0.0741, Train Acc: 97.51%, Val Loss: 0.2359, Val Acc: 93.05%
# Epoch 165, Train Loss: 0.0712, Train Acc: 97.63%, Val Loss: 0.2362, Val Acc: 92.86%
# Epoch 166, Train Loss: 0.0651, Train Acc: 97.91%, Val Loss: 0.2320, Val Acc: 92.95%
# Epoch 167, Train Loss: 0.0611, Train Acc: 98.05%, Val Loss: 0.2476, Val Acc: 92.87%
# Epoch 168, Train Loss: 0.0605, Train Acc: 98.02%, Val Loss: 0.2449, Val Acc: 92.81%
# Epoch 169, Train Loss: 0.0551, Train Acc: 98.24%, Val Loss: 0.2344, Val Acc: 93.18%
# Epoch 170, Train Loss: 0.0505, Train Acc: 98.43%, Val Loss: 0.2266, Val Acc: 93.22%
# Epoch 171, Train Loss: 0.0499, Train Acc: 98.44%, Val Loss: 0.2382, Val Acc: 93.19%
# Epoch 172, Train Loss: 0.0443, Train Acc: 98.68%, Val Loss: 0.2336, Val Acc: 93.17%
# Epoch 173, Train Loss: 0.0432, Train Acc: 98.69%, Val Loss: 0.2119, Val Acc: 93.61%
# Epoch 174, Train Loss: 0.0396, Train Acc: 98.87%, Val Loss: 0.2173, Val Acc: 93.72%
# Epoch 175, Train Loss: 0.0380, Train Acc: 98.90%, Val Loss: 0.2116, Val Acc: 93.73%
# Epoch 176, Train Loss: 0.0336, Train Acc: 99.05%, Val Loss: 0.2155, Val Acc: 93.50%
# Epoch 177, Train Loss: 0.0345, Train Acc: 98.99%, Val Loss: 0.2150, Val Acc: 93.76%
# Epoch 178, Train Loss: 0.0313, Train Acc: 99.10%, Val Loss: 0.2162, Val Acc: 93.72%
# Epoch 179, Train Loss: 0.0304, Train Acc: 99.14%, Val Loss: 0.2193, Val Acc: 93.77%
# Epoch 180, Train Loss: 0.0292, Train Acc: 99.23%, Val Loss: 0.2122, Val Acc: 93.66%
# Epoch 181, Train Loss: 0.0275, Train Acc: 99.21%, Val Loss: 0.2078, Val Acc: 94.00%
# Epoch 182, Train Loss: 0.0264, Train Acc: 99.27%, Val Loss: 0.2038, Val Acc: 94.05%
# Epoch 183, Train Loss: 0.0243, Train Acc: 99.37%, Val Loss: 0.2051, Val Acc: 93.75%
# Epoch 184, Train Loss: 0.0217, Train Acc: 99.49%, Val Loss: 0.1987, Val Acc: 94.00%
# Epoch 185, Train Loss: 0.0231, Train Acc: 99.40%, Val Loss: 0.2026, Val Acc: 94.10%
# Epoch 186, Train Loss: 0.0222, Train Acc: 99.39%, Val Loss: 0.2004, Val Acc: 94.03%
# Epoch 187, Train Loss: 0.0204, Train Acc: 99.49%, Val Loss: 0.1983, Val Acc: 94.12%
# Epoch 188, Train Loss: 0.0202, Train Acc: 99.53%, Val Loss: 0.1987, Val Acc: 94.17%
# Epoch 189, Train Loss: 0.0210, Train Acc: 99.46%, Val Loss: 0.1966, Val Acc: 94.22%
# Epoch 190, Train Loss: 0.0197, Train Acc: 99.50%, Val Loss: 0.1952, Val Acc: 94.22%
# Epoch 191, Train Loss: 0.0181, Train Acc: 99.61%, Val Loss: 0.1955, Val Acc: 94.27%
# Epoch 192, Train Loss: 0.0181, Train Acc: 99.58%, Val Loss: 0.1950, Val Acc: 94.05%
# Epoch 193, Train Loss: 0.0176, Train Acc: 99.60%, Val Loss: 0.1931, Val Acc: 94.13%
# Epoch 194, Train Loss: 0.0180, Train Acc: 99.62%, Val Loss: 0.1955, Val Acc: 94.13%
# Epoch 195, Train Loss: 0.0179, Train Acc: 99.59%, Val Loss: 0.1947, Val Acc: 94.26%
# Epoch 196, Train Loss: 0.0177, Train Acc: 99.59%, Val Loss: 0.1950, Val Acc: 94.22%
# Epoch 197, Train Loss: 0.0174, Train Acc: 99.61%, Val Loss: 0.1947, Val Acc: 94.15%
# Epoch 198, Train Loss: 0.0179, Train Acc: 99.59%, Val Loss: 0.1947, Val Acc: 94.16%
# Epoch 199, Train Loss: 0.0174, Train Acc: 99.59%, Val Loss: 0.1933, Val Acc: 94.21%
# Epoch 200, Train Loss: 0.0174, Train Acc: 99.59%, Val Loss: 0.1929, Val Acc: 94.11%
# Submission1 file saved.
#    ID  Labels
# 0   0       6
# 1   1       1
# 2   2       8
# 3   3       6
# 4   4       9
# 5   5       2
# 6   6       0
# 7   7       2
# 8   8       9
# 9   9       5
